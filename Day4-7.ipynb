# %%
num1=input("Enter the first number:")
num2=input("Enter the second number:")
sum=num1 + num2
print(sum)
# Out:
# Enter the first number: 2
# Enter the second number: 5
# 25

# %%
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number:"))
sum=num1 + num2
print(sum)
# Out:
# Enter the first number: 2
# Enter the second number: 5
# 7

# %%
first_name=input("Enter your first name:")
last_name=input("Enter your last name:")
age=int(input("Enter your age:"))

print(first_name)
print(last_name)
print(age)

print(first_name, last_name, age)

print(first_name," " ,last_name," ", age)
# Out:
# Enter your first name: Vinul
# Enter your last name: Jayawardene
# Enter your age: 14
# Vinul
# Jayawardene
# 14
# Vinul Jayawardene 14
# Vinul   Jayawardene   14

# %%
first_name=input("Enter your first name:")
last_name=input("Enter your last name:")
age=int(input("Enter your age:"))

print("My name is"," ",first_name," ",last_name," ","I am"," ",age," ","years old")
# Out:
# Enter your first name: Vinul
# Enter your last name: Jayawardene
# Enter your age: 14
# My name is   Vinul   Jayawardene   I am   14   years old

# %%
first_name=input("Enter your first name:")
last_name=input("Enter your last name:")
age=int(input("Enter your age:"))

print(f"My name is {first_name} {last_name} and I am {age} years old.")
# Out:
# Enter your first name: Vinul
# Enter your last name: Jayawardene
# Enter your age: 14
# My name is Vinul Jayawardene and I am 14 years old.

# %%
print("Hello\nWorld\nHow\nare\nyou")
# Out:
# Hello
# World
# How
# are
# you

# %%
multiline_speech="""This is line one.\nThis is line two.\nThis is line three."""
print(multiline_speech)
# Out:
# This is line one.
# This is line two.
# This is line three.

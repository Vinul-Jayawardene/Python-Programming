# %%
print("Hai Sri Lanka")
# Out:
# Hai Sri Lanka

# %%
print('Hai Sri Lanka')
# Out:
# Hai Sri Lanka

# %%
Print("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("Hello World")
#
# NameError: name 'Print' is not defined

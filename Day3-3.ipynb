# %%
marks=int(input("Enter your marks:"))
if marks>=50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks: 2
# Fail

# %%
marks=int(input("Enter your marks:"))
if marks>=75:
    print("Grade A")
elif marks>=65:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter your marks: 76
# Grade A

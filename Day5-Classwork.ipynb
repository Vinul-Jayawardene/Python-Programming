# %%
def greet():
    print('Hello World')

greet()
# Out:
# Hello World

# %%
name=input("Enter your name:")
def Name():
    print(f"Hello {name}")


Name()
# Out:
# Enter your name: Vinul
# Hello Vinul

# %%
def result(num1, num2):
    return num1+num2

result(2,4)
# Out:
# 6

# %%
def check_number(a):
    answer=a%2
    if answer==0:
        print("Even")
    else:
        print("Odd")

check_number(1088)
# Out:
# Even

# %%
def square(a):
    return a*a

square(3)
# Out:
# 9

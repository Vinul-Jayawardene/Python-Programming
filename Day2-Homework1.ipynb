# %%
pet=input("Enter your pet's name:")
home=input("Enter your home town:")
job=input("Enter your dream job:")
print(pet)
print(home)
print(job)
# Out:
# Enter your pet's name: Larry
# Enter your home town: New York
# Enter your dream job: Engineer
# Larry
# New York
# Engineer

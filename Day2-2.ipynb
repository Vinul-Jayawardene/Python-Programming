# %%
x=100
print(x)
# Out:
# 100

# %%
y=75
print(y)
# Out:
# 75

# %%
name1="vinul"
print(name1)
# Out:
# vinul

# %%
X=100
x=105
print(X)
print(x)
# Out:
# 100
# 105

# %%
145name="vinul"
print(145name)
# Out:
#   Cell In[11], line 1
#     145name="vinul"
#       ^
# SyntaxError: invalid decimal literal

# %%
name145="vinul"
print(name145)
# Out:
# vinul

# %%
for=20
print(for)
# Out:
#   Cell In[12], line 1
#     for=20
#        ^
# SyntaxError: invalid syntax

# %%
for77=20
print(for77)
# Out:
# 20

# %%
tuple1=()
tuple2=tuple()
print(type(tuple1))
print(type(tuple2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
tuple1=(10,20,30,40,50)
tuple2=tuple((15,18,24,27))
print(tuple1)
print(tuple2)
print(type(tuple1))
print(type(tuple2))
# Out:
# (10, 20, 30, 40, 50)
# (15, 18, 24, 27)
# <class 'tuple'>
# <class 'tuple'>

# %%
mytuple=(10,"John",20,"Anne",30)
print(mytuple[0])
print(mytuple[-1])
# Out:
# 10
# 30

# %%
list1=[10,"John",20,"Anne",30]
print(type(list1))

tuple1=tuple(list1)
print(tuple1)
print(type(tuple1))
# Out:
# <class 'list'>
# (10, 'John', 20, 'Anne', 30)
# <class 'tuple'>

# %%
mytuple=(1,2,2,2,3)
print(mytuple.count(2))
print(mytuple.index(3))
# Out:
# 3
# 4

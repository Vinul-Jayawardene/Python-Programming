# %%
def greet():
    print("Hello, Welcome to Sri Lanka")

# %%
greet()
# Out:
# Hello, Welcome to Sri Lanka

# %%
def calculate(a,b):
    print(a+b)


calculate(5,7)
# Out:
# 12

# %%
calculate(100,9)
# Out:
# 109

# %%
def greeting(name):
    print(f"Hello,{name}!")

greeting("Vinul")
# Out:
# Hello,Vinul!

# %%
def greeting(name="Guest"):
    print(f"Hello,{name}!")

greeting()
greeting("Vinul")
# Out:
# Hello,Guest!
# Hello,Vinul!

# %%
def calculate(a,b):
    return (a+b)
calculate(5,7)
# Out:
# 12

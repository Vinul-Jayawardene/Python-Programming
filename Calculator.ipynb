# %%
        
def repeat():
    def add():
            result=number1+number2
            print(result)

    def sub():
            result=number1-number2
            print(result)

    def mul():
            result=number1*number2
            print(result)

    def div():
            result=number1/number2
            print(result)

    
    option=int(input("What is your chocie?"))
    

    

    

    if option==1:
        number1=int(input("Enter the first value:"))
        number2=int(input("Enter the second value"))
        add()
        repeat()
    elif option==2:
        number1=int(input("Enter the first value:"))
        number2=int(input("Enter the second value"))
        sub()
        repeat()
    elif option==3:
        number1=int(input("Enter the first value:"))
        number2=int(input("Enter the second value"))
        mul()
        repeat()
    elif option==4:
        number1=int(input("Enter the first value:"))
        number2=int(input("Enter the second value"))
        div()
        repeat()
    elif option==5:
        print("Goodbye")
    else:
        print("Please enter a valid choice")
        repeat()

    
print("****Calculator****")
print("Menu")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Exit")
print("Please select to proceed")
repeat()
    5
# Out:
# ****Calculator****
# Menu
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Please select to proceed
# What is your chocie? 3
# Enter the first value: 9999
# Enter the second value 9998
# 99970002
# What is your chocie? 5
# Goodbye

# %% [markdown]
# #####

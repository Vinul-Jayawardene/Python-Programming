# %%
marks=int(input("Enter your marks:"))

if marks>=75 <=100:
    print("A")
elif marks>=65 <=74:
    print("B")
elif marks>=55 <=64:
    print("C")
elif marks>=35 <=54:
    print("S")
else:
    print("F")
# Out:
# Enter your marks: 30
# Fail

# %%
number=int(input("Enter a number:"))
if number>0:
    print("Positive number")
elif number<0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Enter a number: 0
# Zero

# %%
number=int(input("Enter a number:"))
result=number%2
if result==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 3
# Odd number

# %%
Name="Hello Sri Lanka"
print(Name[0])
# Out:
# H

# %%
Name="Hello Sri Lanka"
print(Name[-7])
# Out:
# i

# %%
Name="Hello Sri Lanka"
print(Name[2], Name[10])
# Out:
# l L

# %%
Name="Hello Sri Lanka"
print(Name[1:10])
# Out:
# ello Sri

# %%
Name="Hello Sri Lanka"
print(Name[1:])
# Out:
# ello Sri Lanka

# %%
Name="Hello Sri Lanka"
print(Name.upper())
print(Name.lower())
# Out:
# HELLO SRI LANKA
# hello sri lanka

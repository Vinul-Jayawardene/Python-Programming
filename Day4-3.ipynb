# %%
Fruits_List=["apple","banana","cherry"]
for fruit in Fruits_List:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
student={"name":"Vinul", "age":30, "grade":"A"}
for key in student:
    print(key)
# Out:
# name
# age
# grade

# %%
for letter in "Python":
    print(letter)
# Out:
# P
# y
# t
# h
# o
# n

# %%
for letter in "Python":
    print(letter,end="")
# Out:
# Python

# %%
for letter in "Python":
    print(letter,end=" ")
# Out:
# P y t h o n

# %%
for letter in "Python":
    print(letter,end="_")
# Out:
# P_y_t_h_o_n_

# %%
for letter in "Python":
    print(letter,end=",")
# Out:
# P,y,t,h,o,n,

# %%
for letter in "Python":
    print(letter,end="...")
# Out:
# P...y...t...h...o...n...

# %%
for letter in "Python":
    print(letter,end="         ")
# Out:
# P         y         t         h         o         n

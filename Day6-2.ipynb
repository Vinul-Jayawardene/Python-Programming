# %%
numbers=[5,7,33,11,18,25,8]
numbers.sort()
print(numbers)
# Out:
# [5, 7, 8, 11, 18, 25, 33]

# %%
numbers.reverse()
print(numbers)
# Out:
# [33, 25, 18, 11, 8, 7, 5]

# %%
print(len(numbers))
# Out:
# 7

# %%
print(numbers.index(8))
# Out:
# 4

# %%
print(numbers.count(7))
# Out:
# 1

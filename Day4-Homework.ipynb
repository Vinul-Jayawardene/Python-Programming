# %%
password="abc123"
answer=input("Enter the password")
while answer!=password:
    print("Try again")
    answer=input("Enter the password")
print("Access granted")
# Out:
# Enter the password asasa
# Try again
# Enter the password sasasas
# Try again
# Enter the password abc123
# Access granted

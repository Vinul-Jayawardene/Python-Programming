# %%
name="Senaka"
print(name)
print(type(name))
# Out:
# Senaka
# <class 'str'>

# %%
mylist1=[]
print(mylist1)
print(type(mylist1))

mylist2=list()
print(mylist2)
print(type(mylist2))

mylist3=[10,20,30,40,50]
print(mylist3)
print(type(mylist3))

mylist4=[10,20,30,40,50,True,False,"Vinul"]
print(mylist4)
print(type(mylist4))
# Out:
# []
# <class 'list'>
# []
# <class 'list'>
# [10, 20, 30, 40, 50]
# <class 'list'>
# [10, 20, 30, 40, 50, True, False, 'Vinul']
# <class 'list'>

# %%
numbers=[5,10,15,20]
numbers.append(25)
print(numbers)
# Out:
# [5, 10, 15, 20, 25]

# %%
fruits=["apple", "banana", "mango"]
fruits[1]="orange"
print(fruits)

fruits.insert(1,"cherry")
print(fruits)
# Out:
# ['apple', 'orange', 'mango']
# ['apple', 'cherry', 'orange', 'mango']

# %%
mylist3=[10,20,30,40,50]
print(mylist3)
print(type(mylist3))

mylist3.remove(20)
print(mylist3)
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>
# [10, 30, 40, 50]

# %%
mylist3=[10,20,30,40,50]
print(mylist3)
print(type(mylist3))

mylist3.pop()
print(mylist3)
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>
# [10, 20, 30, 40]

# %%
mylist3=[10,20,30,40,50]
print(mylist3)
print(type(mylist3))

mylist3.pop(2)
print(mylist3)
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>
# [10, 20, 40, 50]

# %%
mylist3=[10,20,30,40,50]
print(mylist3)
print(type(mylist3))

mylist3.clear()
print(mylist3)
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>
# []

# %%
mylist=[20,"john",34,False,"Anne"]
print(mylist[0])
print(mylist[:3])
print(mylist[::-1])
print(mylist[:])
print(mylist[2:5])
print(mylist[2:])
print(mylist[2:5:2])
# Out:
# 20
# [20, 'john', 34]
# ['Anne', False, 34, 'john', 20]
# [20, 'john', 34, False, 'Anne']
# [34, False, 'Anne']
# [34, False, 'Anne']
# [34, 'Anne']

# %%
mylist=[20, "john", [20,24,29,33]]
print(mylist[2])
print(mylist[2][1])
# Out:
# [20, 24, 29, 33]
# 24

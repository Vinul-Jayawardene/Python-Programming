# %%
x=100
print(x)
# Out:
# 100

# %%
x=input("Enter the value:")
# Out:
# Enter the value: 100

# %%
x=input("Enter the value:")
print(x)
# Out:
# Enter the value: 100
# 100

# %%
x=input("Enter your name:")
y=input("Enter your favourite colour:")
print(x)
print(y)
# Out:
# Enter your name: Vinul
# Enter your favourite colour: Black
# Vinul
# Black

# %%
x=input("Enter your name:")
y=input("Enter your favourite colour:")
z=input("Enter the marks of subject of English:")
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))
# Out:
# Enter your name: Vinul
# Enter your favourite colour: Black
# Enter the marks of subject of English: 76
# Vinul
# Black
# 76
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x=input("Enter your name:")
y=input("Enter your favourite colour:")
z=int(input("Enter the marks of subject of English:"))
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))
# Out:
# Enter your name: Vinul
# Enter your favourite colour: Black
# Enter the marks of subject of English: 76
# Vinul
# Black
# 76
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
x=input("Enter your name:")
y=input("Enter your favourite colour:")
z=int(input("Enter the marks of subject of English:"))
cels=float(input(("Enter the value in celsius:")))
print(x)
print(y)
print(z)
print(cels)
print(type(x))
print(type(y))
print(type(z))
print(type(cels))
# Out:
# Enter your name: Vinul
# Enter your favourite colour: Black
# Enter the marks of subject of English: 76
# Enter the value in celsius: 31.4
# Vinul
# Black
# 76
# 31.4
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>

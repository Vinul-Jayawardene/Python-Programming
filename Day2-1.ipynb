# %%
x=100
y=75
print(x)
print(y)
print(x,y)
# Out:
# 100
# 75
# 100 75

# %%
x=100
y=75
name1=vinul
print(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 x=100
#       2 y=75
# ----> 3 name1=vinul
#       4 print(x)
#       5 print(y)
#
# NameError: name 'vinul' is not defined

# %%
x=100
y=75
name1="vinul"
print(x)
print(y)
print(name1)
# Out:
# 100
# 75
# vinul

# %%
x=100
y=75
name1="vinul"
name2="Colombo"
print(x)
print(y)
print(name1)
print(name2)
# Out:
# 100
# 75
# vinul
# Colombo

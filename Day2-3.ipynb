# %%
x=100
print(x)
# Out:
# 100

# %%
x=100
print(x)
print(type(x))
# Out:
# 100
# <class 'int'>

# %%
y="vinul"
print(y)
# Out:
# vinul

# %%
y="vinul"
print(y)
print(type(y))
# Out:
# vinul
# <class 'str'>

# %%
z=3.14
print(z)
# Out:
# 3.14

# %%
z=3.14
print(z)
print(type(z))
# Out:
# 3.14
# <class 'float'>

# %%
is_road_closed=True
print(type(is_road_closed))
# Out:
# <class 'bool'>

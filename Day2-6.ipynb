# %%
x=5
y=7
print(x+y)
print(type(x))
# Out:
# 12
# <class 'int'>

# %%
x=15
y=8
print(x+y)
print(type(x))
# Out:
# 23
# <class 'int'>

# %%
x=15
y=8
print(x+y)
print(x-y)
print(x/y)
print(x//y)
print(x%y)
print(x*y)
print(x**2)
# Out:
# 23
# 7
# 1.875
# 1
# 7
# 120
# 225

# %%
result=(5+3)*2**2-10/5+7%3
print(result)
# Out:
# 31.0

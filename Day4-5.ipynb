# %%
import time
battery=10
while battery>0:
    print("Battery Level",battery)
    battery-=1
    time.sleep(1)
print("Battery Empty")
# Out:
# Battery Level 10
# Battery Level 9
# Battery Level 8
# Battery Level 7
# Battery Level 6
# Battery Level 5
# Battery Level 4
# Battery Level 3
# Battery Level 2
# Battery Level 1
# Battery Empty

# %%
age=-1
while age<0:
    age=int(input("Enter a valid age:"))
print("Thank you")
# Out:
# Enter a valid age: -2
# Enter a valid age: 2
# Thank you

# %%
choice=""
while choice!="3":
    print("1.Add\n2.View\n3.Exit")
    choice=input("Choose an option:")
print("Goodbye")
# Out:
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 1
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 2
# 1.Add
# 2.View
# 3.Exit
# Choose an option: 3
# Goodbye

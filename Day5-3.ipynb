# %%
for i in range(1,11,1):
    if i==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
def greet():
    pass

# %%
for i in range(1,11,1):
    pass

# %%
for i in range(1,11,1):
    if i==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

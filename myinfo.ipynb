# %%
print("My name is Vinul Jayawardene.")
print("I am a student at Louvre College.")
print("I am currently preparing for my Cambridge O-Level examinations.")
print("I am also attending a Python programming course.")
# Out:
# My name is Vinul Jayawardene.
# I am a student at Louvre College.
# I am currently preparing for my Cambridge O-Level examinations.
# I am also attending a Python programming course.

# %%
item_name=input("Enter item name:")
amount_available=int(input("Enter the amount available:"))
print(item_name)
print(type(item_name))
print(amount_available)
print(type(amount_available))
# Out:
# Enter item name: ball
# Enter the amount available: 3
# ball
# <class 'str'>
# 3
# <class 'int'>
